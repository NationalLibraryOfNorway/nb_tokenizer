# %% [markdown]
# ## Tokenisere med original tokenisator

# %%
import time
import nb_tokenizer as nb
import os

# %%
# folder = 'bokselskap'  'maalfrid'  'nbdigital'  'stortinget'

folder = 'bokselskap'

input_folder = '../../tekster/input/' + folder
output_folder = '../../tekster/output/orig_tokenisator/' + folder

# %%
input_files = [f for f in os.listdir(input_folder) if f.endswith('.txt')]

# %%
t0 = time.process_time()

for filename in input_files:
    input_path = os.path.join(input_folder, filename)

    with open(input_path, 'r') as file:
        text = file.read()
    
    tokens = nb.tokenize(text)

    output_filename = filename.replace('.txt', '_orig.txt')
    output_path = os.path.join(output_folder, output_filename)

    with open(output_path, 'w') as file:
        [file.write(i+'\n') for i in tokens]

t1 = time.process_time()
t = t1 - t0

print(f"tid original: {t}")
