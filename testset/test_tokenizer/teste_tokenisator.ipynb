# %%
import sys
import os
from datetime import datetime

# %%
parent_dir = os.path.abspath(os.path.join(os.getcwd(), "../../"))
sys.path.append(parent_dir)

# %%
from src import nb_tokenizer

# %%
with open('../testsett.txt', 'r') as file:
    testsett = file.read()

# %%
tokenisert_testsett = nb_tokenizer.tokenize(testsett)

# %%
#tokenisert_testsett

# %%
now = datetime.now()
timestamp = now.strftime("%y%m%d_%H%M%S")

ut_filnavn = 'tokenisert_testsett_' + timestamp + '.txt'
ut_filnavn

# %%
with open(ut_filnavn, 'w') as file:
    [file.write(i+'\n') for i in tokenisert_testsett]
