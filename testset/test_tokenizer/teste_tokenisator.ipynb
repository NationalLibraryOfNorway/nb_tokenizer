# %%
import sys
import os

# %%
parent_dir = os.path.abspath(os.path.join(os.getcwd(), "../../"))
sys.path.append(parent_dir)

# %%
from src import nb_tokenizer

# %%
with open('../testsett.txt', 'r') as file:
    testsett = file.read()

# %%
tokenisert_testsett = nb_tokenizer.tokenize(testsett)

# %%
#tokenisert_testsett

# %%
with open('tokenisert_testsett_3.txt', 'w') as file:
    [file.write(i+'\n') for i in tokenisert_testsett]

# %%
#Legge inn tidsstempel i filnavnet
